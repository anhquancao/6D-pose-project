# %%
from lib.network import PoseNetRGBOnly
from lib.loss import Loss
from lib.utils import setup_logger
from datasets.linemod.dataset import PoseDataset as PoseDataset_linemod
import torch
import os
from torch import optim
import numpy as np
import time
from torch.autograd import Variable
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
num_objects = 5
num_points = 500
outf = 'trained_models/linemod'
log_dir = 'experiments/logs/linemod'
repeat_epoch = 20
decay_margin = 0.016
decay_start = False
lr_rate = 0.3
w_rate = 0.3

# %%
estimator = PoseNetRGBOnly(num_points=num_points, num_obj = num_objects)
estimator.cuda();
lr = 0.0001
optimizer = optim.Adam(estimator.parameters(), lr=lr)

# %%
model = 'trained_models/linemod/pose_model_12_0.09392938120923575.pth'
estimator.load_state_dict(torch.load(model))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-8c87d8667552> in <module>
#       1 model = 'trained_models/linemod/pose_model_12_0.09392938120923575.pth'
# ----> 2 estimator.load_state_dict(torch.load(model))
#
# ~/.conda/envs/visual/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     379             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     380         new_fd = True
# --> 381         f = open(f, 'rb')
#     382     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     383         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'trained_models/linemod/pose_model_12_0.09392938120923575.pth'

# %%
dataset_root = "./datasets/linemod/Linemod_preprocessed"
noise_trans = 0.03
refine_start = False
decay_start = False


dataset = PoseDataset_linemod('train', 
                              num_points, 
                              True, 
                              dataset_root, 
                              noise_trans, 
                              refine_start)

workers = 4
dataloader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=1, 
                                         shuffle=True, 
                                         num_workers=workers)
# Out:
# Object 2 buffer loaded
# Object 4 buffer loaded
# Object 5 buffer loaded
# Object 10 buffer loaded
# Object 11 buffer loaded

# %%
test_dataset = PoseDataset_linemod('test', 
                                   num_points, 
                                   False, 
                                   dataset_root, 
                                   0.0, 
                                   refine_start)
testdataloader = torch.utils.data.DataLoader(test_dataset, 
                                             batch_size=1, 
                                             shuffle=False, 
                                             num_workers=workers)
# Out:
# Object 2 buffer loaded
# Object 4 buffer loaded
# Object 5 buffer loaded
# Object 10 buffer loaded
# Object 11 buffer loaded

# %%
sym_list = dataset.get_sym_list()
num_points_mesh = dataset.get_num_points_mesh()

# %%
print('>>>>>>>>----------Dataset loaded!---------<<<<<<<<\nlength of the training set: {0}\nlength of the testing set: {1}\nnumber of sample points on mesh: {2}\nsymmetry object list: {3}'
      .format(len(dataset), 
              len(test_dataset), 
              num_points_mesh, 
              sym_list))
# Out:
# >>>>>>>>----------Dataset loaded!---------<<<<<<<<
# length of the training set: 914
# length of the testing set: 515
# number of sample points on mesh: 500
# symmetry object list: [3, 4]

# %%
criterion = Loss(num_points_mesh, sym_list)

# %%
start_epoch = 1
nepoch = 16
w = 0.015
batch_size = 8

# %%
next(iter(dataloader))[1].shape
# Out:
# torch.Size([1, 1, 500])

# %%
lr *= lr_rate
w *= w_rate
optimizer = optim.Adam(estimator.parameters(), lr=lr)

# %%
best_test = np.Inf
print_every = 50

if start_epoch == 1:
    for log in os.listdir(log_dir):
        if '.ipyn' not in log:
            os.remove(os.path.join(log_dir, log))
st_time = time.time()

for epoch in range(start_epoch, nepoch):
    logger = setup_logger('epoch%d' % epoch, os.path.join(log_dir, 'epoch_%d_log.txt' % epoch))
    mess = 'Train time {0}'.format(time.strftime("%Hh %Mm %Ss", time.gmtime(time.time() - st_time)) + ', ' + 'Training started')
    print(mess)
    logger.info(mess)
    
    train_count = 0
    train_dis_avg = 0.0
    
    estimator.train()
    optimizer.zero_grad()

    for rep in range(repeat_epoch):
        for i, data in enumerate(dataloader, 0):
            points, choose, img, target, model_points, idx = data 
            points, choose, img, target, model_points, idx = Variable(points).cuda(), \
                                                             Variable(choose).cuda(), \
                                                             Variable(img).cuda(), \
                                                             Variable(target).cuda(), \
                                                             Variable(model_points).cuda(), \
                                                             Variable(idx).cuda()
            
            pred_r, pred_t, pred_c, emb = estimator(img, choose, idx)
            loss, dis, _, _ = criterion(pred_r, pred_t, pred_c, target, 
                                  model_points, idx,
                                  points, w, refine_start)
            loss.backward()
            
            train_dis_avg += dis.item()
            train_count += 1
            if train_count % batch_size == 0:
                
                mess = 'Train time {0} Epoch {1} Batch {2} Frame {3} Avg_dis:{4}'.format(
                        time.strftime("%Hh %Mm %Ss", time.gmtime(time.time() - st_time)), 
                        epoch, int(train_count / batch_size), 
                        train_count, 
                        train_dis_avg / batch_size)
                logger.info(mess)
                
                optimizer.step()
                optimizer.zero_grad()
                train_dis_avg = 0
                
                
                if train_count % print_every == 0:
                    print(mess)
            
            if train_count != 0 and train_count % 500 == 0:                    
                torch.save(estimator.state_dict(), '{0}/pose_model_current.pth'.format(outf))
            
    print('>>>>>>>>----------epoch {0} train finish---------<<<<<<<<'.format(epoch))
    
    test_dis = 0.0
    test_count = 0
    estimator.eval()
    
    for j, data in enumerate(testdataloader, 0):
        points, choose, img, target, model_points, idx = data
        points, choose, img, target, model_points, idx = Variable(points).cuda(), \
                                                         Variable(choose).cuda(), \
                                                         Variable(img).cuda(), \
                                                         Variable(target).cuda(), \
                                                         Variable(model_points).cuda(), \
                                                         Variable(idx).cuda()
       
        pred_r, pred_t, pred_c, emb = estimator(img, choose, idx)
        _, dis, _, _ = criterion(pred_r, pred_t, pred_c, target,
                           model_points, idx, 
                           points, w, refine_start)
        test_dis += dis.item()
        mess = 'Test time {0} Test Frame No.{1} dis:{2}'.format(time.strftime("%Hh %Mm %Ss", time.gmtime(time.time() - st_time)), test_count, dis)
        logger.info(mess)
        
        test_count += 1
    test_dis = test_dis / test_count
    mess = 'Test time {0} Epoch {1} TEST FINISH Avg dis: {2}'.format(time.strftime("%Hh %Mm %Ss", time.gmtime(time.time() - st_time)), epoch, test_dis)
    print(mess)
    logger.info(mess)
    
    if test_dis <= best_test:
        best_test = test_dis
        torch.save(estimator.state_dict(), '{0}/pose_model_{1}_{2}.pth'.format(outf, epoch, test_dis))
        print(epoch, '>>>>>>>>----------BEST TEST MODEL SAVED---------<<<<<<<<')
        
    if best_test < decay_margin and not decay_start:
        decay_start = True
        lr *= lr_rate
        w *= w_rate
        optimizer = optim.Adam(estimator.parameters(), lr=lr)
# Out:
# Test time 00h 33m 42s Epoch 2 TEST FINISH Avg dis: 0.01673948421206289
# 2 >>>>>>>>----------BEST TEST MODEL SAVED---------<<<<<<<<
# Train time 00h 33m 42s, Training started
# Train time 00h 33m 53s Epoch 3 Batch 25 Frame 200 Avg_dis:0.018506382941268384
# Train time 00h 34m 04s Epoch 3 Batch 50 Frame 400 Avg_dis:0.013413167383987457
# Train time 00h 34m 15s Epoch 3 Batch 75 Frame 600 Avg_dis:0.012544608442112803
# Train time 00h 34m 26s Epoch 3 Batch 100 Frame 800 Avg_dis:0.01687428425066173
# Train time 00h 34m 37s Epoch 3 Batch 125 Frame 1000 Avg_dis:0.009262320643756539
# Train time 00h 34m 48s Epoch 3 Batch 150 Frame 1200 Avg_dis:0.01629018585663289
# Train time 00h 34m 59s Epoch 3 Batch 175 Frame 1400 Avg_dis:0.00921548210317269
# Train time 00h 35m 10s Epoch 3 Batch 200 Frame 1600 Avg_dis:0.009264854132197797
# Train time 00h 35m 21s Epoch 3 Batch 225 Frame 1800 Avg_dis:0.010205122991465032
# Train time 00h 35m 32s Epoch 3 Batch 250 Frame 2000 Avg_dis:0.022535425494425
# Train time 00h 35m 43s Epoch 3 Batch 275 Frame 2200 Avg_dis:0.012906163930892944
# Train time 00h 35m 53s Epoch 3 Batch 300 Frame 2400 Avg_dis:0.01255993521772325
# Train time 00h 36m 04s Epoch 3 Batch 325 Frame 2600 Avg_dis:0.015112789929844439
# Train time 00h 36m 16s Epoch 3 Batch 350 Frame 2800 Avg_dis:0.017951143439859152
# Train time 00h 36m 26s Epoch 3 Batch 375 Frame 3000 Avg_dis:0.016881446237675846
# Train time 00h 36m 37s Epoch 3 Batch 400 Frame 3200 Avg_dis:0.012159736710600555
# Train time 00h 36m 48s Epoch 3 Batch 425 Frame 3400 Avg_dis:0.019478904083371162
# Train time 00h 36m 59s Epoch 3 Batch 450 Frame 3600 Avg_dis:0.013483073096722364
# Train time 00h 37m 10s Epoch 3 Batch 475 Frame 3800 Avg_dis:0.011104444274678826
# Train time 00h 37m 21s Epoch 3 Batch 500 Frame 4000 Avg_dis:0.015151977422647178
# Train time 00h 37m 32s Epoch 3 Batch 525 Frame 4200 Avg_dis:0.012636582599952817
# Train time 00h 37m 42s Epoch 3 Batch 550 Frame 4400 Avg_dis:0.01245811302214861
# Train time 00h 37m 54s Epoch 3 Batch 575 Frame 4600 Avg_dis:0.01413755479734391
# Train time 00h 38m 04s Epoch 3 Batch 600 Frame 4800 Avg_dis:0.012408448266796768
# Train time 00h 38m 15s Epoch 3 Batch 625 Frame 5000 Avg_dis:0.018803696846589446
# Train time 00h 38m 26s Epoch 3 Batch 650 Frame 5200 Avg_dis:0.01411846064729616
# Train time 00h 38m 37s Epoch 3 Batch 675 Frame 5400 Avg_dis:0.013936789386207238
# Train time 00h 38m 48s Epoch 3 Batch 700 Frame 5600 Avg_dis:0.015185477561317384
# Train time 01h 01m 32s Epoch 4 Batch 1500 Frame 12000 Avg_dis:0.009886545652989298
# Train time 01h 01m 43s Epoch 4 Batch 1525 Frame 12200 Avg_dis:0.015223361435346305
# Train time 01h 01m 53s Epoch 4 Batch 1550 Frame 12400 Avg_dis:0.014074971724767238
# Train time 01h 02m 04s Epoch 4 Batch 1575 Frame 12600 Avg_dis:0.009293486655224115
# Train time 01h 02m 15s Epoch 4 Batch 1600 Frame 12800 Avg_dis:0.012098876119125634
# Train time 01h 02m 26s Epoch 4 Batch 1625 Frame 13000 Avg_dis:0.012079118168912828
# Train time 01h 02m 37s Epoch 4 Batch 1650 Frame 13200 Avg_dis:0.01689144124975428
# Train time 01h 02m 48s Epoch 4 Batch 1675 Frame 13400 Avg_dis:0.010058936255518347
# Train time 01h 02m 59s Epoch 4 Batch 1700 Frame 13600 Avg_dis:0.008718765340745449
# Train time 01h 03m 10s Epoch 4 Batch 1725 Frame 13800 Avg_dis:0.015488622128032148
# Train time 01h 03m 21s Epoch 4 Batch 1750 Frame 14000 Avg_dis:0.014691393065731972
# Train time 01h 03m 31s Epoch 4 Batch 1775 Frame 14200 Avg_dis:0.010092748561874032
# Train time 01h 03m 42s Epoch 4 Batch 1800 Frame 14400 Avg_dis:0.01390129013452679
# Train time 01h 03m 53s Epoch 4 Batch 1825 Frame 14600 Avg_dis:0.013016292825341225
# Train time 01h 04m 04s Epoch 4 Batch 1850 Frame 14800 Avg_dis:0.011339079472236335
# Train time 01h 04m 15s Epoch 4 Batch 1875 Frame 15000 Avg_dis:0.009801955020520836
# Train time 01h 04m 26s Epoch 4 Batch 1900 Frame 15200 Avg_dis:0.010654220066498965
# Train time 01h 04m 36s Epoch 4 Batch 1925 Frame 15400 Avg_dis:0.012856728921178728
# Train time 01h 04m 48s Epoch 4 Batch 1950 Frame 15600 Avg_dis:0.009348078281618655
# Train time 01h 04m 58s Epoch 4 Batch 1975 Frame 15800 Avg_dis:0.007120069698430598
# Train time 01h 05m 09s Epoch 4 Batch 2000 Frame 16000 Avg_dis:0.010115653974935412
# Train time 01h 05m 20s Epoch 4 Batch 2025 Frame 16200 Avg_dis:0.015828387811779976
# Train time 01h 05m 31s Epoch 4 Batch 2050 Frame 16400 Avg_dis:0.012200355064123869
# Train time 01h 05m 42s Epoch 4 Batch 2075 Frame 16600 Avg_dis:0.010538359289057553
# Train time 01h 05m 53s Epoch 4 Batch 2100 Frame 16800 Avg_dis:0.013469132652971894
# Train time 01h 06m 04s Epoch 4 Batch 2125 Frame 17000 Avg_dis:0.01132080372190103
# Train time 01h 06m 14s Epoch 4 Batch 2150 Frame 17200 Avg_dis:0.013381003314862028
# Train time 01h 06m 25s Epoch 4 Batch 2175 Frame 17400 Avg_dis:0.011512746568769217
# Train time 01h 06m 36s Epoch 4 Batch 2200 Frame 17600 Avg_dis:0.012193358386866748
# Train time 01h 06m 47s Epoch 4 Batch 2225 Frame 17800 Avg_dis:0.01186148781562224
# Train time 01h 06m 58s Epoch 4 Batch 2250 Frame 18000 Avg_dis:0.015876949531957507
# Train time 01h 07m 09s Epoch 4 Batch 2275 Frame 18200 Avg_dis:0.008601951354648918
# >>>>>>>>----------epoch 4 train finish---------<<<<<<<<
# Test time 01h 07m 29s Epoch 4 TEST FINISH Avg dis: 0.015266920312407237
# 4 >>>>>>>>----------BEST TEST MODEL SAVED---------<<<<<<<<
# Train time 01h 07m 30s, Training started
# Train time 01h 07m 41s Epoch 5 Batch 25 Frame 200 Avg_dis:0.007300801866222173
# Train time 01h 07m 52s Epoch 5 Batch 50 Frame 400 Avg_dis:0.007315904425922781
# Train time 01h 08m 02s Epoch 5 Batch 75 Frame 600 Avg_dis:0.009656117705162615
# Train time 01h 08m 13s Epoch 5 Batch 100 Frame 800 Avg_dis:0.008729554654564708
# Train time 01h 08m 24s Epoch 5 Batch 125 Frame 1000 Avg_dis:0.011432813480496407
# Train time 01h 08m 35s Epoch 5 Batch 150 Frame 1200 Avg_dis:0.009425712167285383
# Train time 01h 08m 46s Epoch 5 Batch 175 Frame 1400 Avg_dis:0.009755570499692112
# Train time 01h 08m 56s Epoch 5 Batch 200 Frame 1600 Avg_dis:0.011189963202923536
# Train time 01h 09m 07s Epoch 5 Batch 225 Frame 1800 Avg_dis:0.011535646568518132
# Train time 01h 09m 18s Epoch 5 Batch 250 Frame 2000 Avg_dis:0.012716795841697603
# Train time 01h 09m 29s Epoch 5 Batch 275 Frame 2200 Avg_dis:0.009897283744066954
# Train time 01h 09m 39s Epoch 5 Batch 300 Frame 2400 Avg_dis:0.012829347630031407
# Train time 01h 09m 50s Epoch 5 Batch 325 Frame 2600 Avg_dis:0.009289632725995034
# Train time 01h 10m 01s Epoch 5 Batch 350 Frame 2800 Avg_dis:0.010227939928881824
# Train time 01h 10m 12s Epoch 5 Batch 375 Frame 3000 Avg_dis:0.015143245022045448
# Train time 01h 10m 23s Epoch 5 Batch 400 Frame 3200 Avg_dis:0.011278570047579706
# Train time 01h 10m 34s Epoch 5 Batch 425 Frame 3400 Avg_dis:0.009667441016063094
# Train time 01h 10m 45s Epoch 5 Batch 450 Frame 3600 Avg_dis:0.010407029243651778
# Train time 01h 10m 56s Epoch 5 Batch 475 Frame 3800 Avg_dis:0.01402634393889457
# Train time 01h 11m 07s Epoch 5 Batch 500 Frame 4000 Avg_dis:0.008257508685346693
# Train time 01h 11m 18s Epoch 5 Batch 525 Frame 4200 Avg_dis:0.009076892747543752
# Train time 01h 11m 29s Epoch 5 Batch 550 Frame 4400 Avg_dis:0.011590921320021152
# Train time 01h 11m 40s Epoch 5 Batch 575 Frame 4600 Avg_dis:0.009873904462438077
# Train time 01h 11m 50s Epoch 5 Batch 600 Frame 4800 Avg_dis:0.016067985503468663
# Train time 01h 12m 01s Epoch 5 Batch 625 Frame 5000 Avg_dis:0.011816772050224245
# Train time 01h 12m 12s Epoch 5 Batch 650 Frame 5200 Avg_dis:0.013310643495060503
# Train time 01h 12m 23s Epoch 5 Batch 675 Frame 5400 Avg_dis:0.008146617328748107
# Train time 01h 18m 09s Epoch 5 Batch 1475 Frame 11800 Avg_dis:0.008960000064689666
# Train time 01h 18m 20s Epoch 5 Batch 1500 Frame 12000 Avg_dis:0.009916637907736003
# Train time 01h 18m 31s Epoch 5 Batch 1525 Frame 12200 Avg_dis:0.00866052252240479
# Train time 01h 18m 42s Epoch 5 Batch 1550 Frame 12400 Avg_dis:0.009647985512856394
# Train time 01h 18m 53s Epoch 5 Batch 1575 Frame 12600 Avg_dis:0.008388466609176248
# Train time 01h 19m 04s Epoch 5 Batch 1600 Frame 12800 Avg_dis:0.011579790443647653
# Train time 01h 19m 15s Epoch 5 Batch 1625 Frame 13000 Avg_dis:0.011287088738754392
# Train time 01h 19m 26s Epoch 5 Batch 1650 Frame 13200 Avg_dis:0.00801226426847279
# Train time 01h 19m 36s Epoch 5 Batch 1675 Frame 13400 Avg_dis:0.008453852555248886
# Train time 01h 19m 47s Epoch 5 Batch 1700 Frame 13600 Avg_dis:0.011106595280580223
# Train time 01h 19m 58s Epoch 5 Batch 1725 Frame 13800 Avg_dis:0.016278113587759435
# Train time 01h 20m 09s Epoch 5 Batch 1750 Frame 14000 Avg_dis:0.006776825699489564
# Train time 01h 20m 20s Epoch 5 Batch 1775 Frame 14200 Avg_dis:0.01094862780882977
# Train time 01h 20m 31s Epoch 5 Batch 1800 Frame 14400 Avg_dis:0.008926287904614583
# Train time 01h 20m 41s Epoch 5 Batch 1825 Frame 14600 Avg_dis:0.008385295222979039
# Train time 01h 20m 52s Epoch 5 Batch 1850 Frame 14800 Avg_dis:0.009654026478528976
# Train time 01h 21m 03s Epoch 5 Batch 1875 Frame 15000 Avg_dis:0.01012422883650288
# Train time 01h 21m 14s Epoch 5 Batch 1900 Frame 15200 Avg_dis:0.01008530321996659
# Train time 01h 21m 24s Epoch 5 Batch 1925 Frame 15400 Avg_dis:0.013553788012359291
# Train time 01h 21m 36s Epoch 5 Batch 1950 Frame 15600 Avg_dis:0.00894208560930565
# Train time 01h 21m 47s Epoch 5 Batch 1975 Frame 15800 Avg_dis:0.011176773114129901
# Train time 01h 21m 57s Epoch 5 Batch 2000 Frame 16000 Avg_dis:0.008232701395172626
# Train time 01h 22m 08s Epoch 5 Batch 2025 Frame 16200 Avg_dis:0.012605186377186328
# Train time 01h 22m 19s Epoch 5 Batch 2050 Frame 16400 Avg_dis:0.008322687994223088
# Train time 01h 22m 30s Epoch 5 Batch 2075 Frame 16600 Avg_dis:0.008264071366284043
# Train time 01h 22m 41s Epoch 5 Batch 2100 Frame 16800 Avg_dis:0.007196762831881642
# Train time 01h 22m 52s Epoch 5 Batch 2125 Frame 17000 Avg_dis:0.013134800596162677
# Train time 01h 23m 03s Epoch 5 Batch 2150 Frame 17200 Avg_dis:0.009408745914697647
# Train time 01h 23m 14s Epoch 5 Batch 2175 Frame 17400 Avg_dis:0.009081411932129413
# Train time 01h 23m 25s Epoch 5 Batch 2200 Frame 17600 Avg_dis:0.01193351490655914
# Train time 01h 23m 35s Epoch 5 Batch 2225 Frame 17800 Avg_dis:0.010283290117513388
# Train time 01h 23m 46s Epoch 5 Batch 2250 Frame 18000 Avg_dis:0.015001273655798286
# Train time 01h 23m 57s Epoch 5 Batch 2275 Frame 18200 Avg_dis:0.014544482692144811
# >>>>>>>>----------epoch 5 train finish---------<<<<<<<<
# Test time 01h 24m 18s Epoch 5 TEST FINISH Avg dis: 0.014421568692490025
# 5 >>>>>>>>----------BEST TEST MODEL SAVED---------<<<<<<<<
# Train time 01h 24m 18s, Training started
# Train time 01h 24m 30s Epoch 6 Batch 25 Frame 200 Avg_dis:0.010768486943561584
# Train time 01h 24m 40s Epoch 6 Batch 50 Frame 400 Avg_dis:0.014018713845871389
# Train time 01h 24m 51s Epoch 6 Batch 75 Frame 600 Avg_dis:0.0091498137335293
# Train time 01h 25m 02s Epoch 6 Batch 100 Frame 800 Avg_dis:0.00913460343144834
# Train time 01h 25m 13s Epoch 6 Batch 125 Frame 1000 Avg_dis:0.012947890441864729
# Train time 01h 25m 24s Epoch 6 Batch 150 Frame 1200 Avg_dis:0.011826545291114599
# Train time 01h 25m 34s Epoch 6 Batch 175 Frame 1400 Avg_dis:0.009347760467790067
# Train time 01h 25m 45s Epoch 6 Batch 200 Frame 1600 Avg_dis:0.01085166254779324
# Train time 01h 25m 56s Epoch 6 Batch 225 Frame 1800 Avg_dis:0.012641276349313557
# Train time 01h 26m 07s Epoch 6 Batch 250 Frame 2000 Avg_dis:0.011424378317315131
# Train time 01h 26m 18s Epoch 6 Batch 275 Frame 2200 Avg_dis:0.013868044887203723
# Train time 01h 26m 29s Epoch 6 Batch 300 Frame 2400 Avg_dis:0.00925850955536589
# Train time 01h 26m 40s Epoch 6 Batch 325 Frame 2600 Avg_dis:0.012048031785525382
# Train time 01h 26m 51s Epoch 6 Batch 350 Frame 2800 Avg_dis:0.012654479418415576
# Train time 01h 27m 02s Epoch 6 Batch 375 Frame 3000 Avg_dis:0.00910537812160328
# Train time 01h 27m 12s Epoch 6 Batch 400 Frame 3200 Avg_dis:0.01374976389342919
# Train time 01h 27m 23s Epoch 6 Batch 425 Frame 3400 Avg_dis:0.009483577567152679
# Train time 01h 27m 34s Epoch 6 Batch 450 Frame 3600 Avg_dis:0.013456627551931888
# Train time 01h 27m 45s Epoch 6 Batch 475 Frame 3800 Avg_dis:0.014051827252842486
# Train time 01h 27m 56s Epoch 6 Batch 500 Frame 4000 Avg_dis:0.009426577540580183
# Train time 01h 28m 07s Epoch 6 Batch 525 Frame 4200 Avg_dis:0.009917339775711298
# Train time 01h 28m 18s Epoch 6 Batch 550 Frame 4400 Avg_dis:0.009459553170017898
# Train time 01h 28m 29s Epoch 6 Batch 575 Frame 4600 Avg_dis:0.012813737208489329
# Train time 01h 28m 40s Epoch 6 Batch 600 Frame 4800 Avg_dis:0.011111045139841735
# Train time 01h 28m 51s Epoch 6 Batch 625 Frame 5000 Avg_dis:0.014551750966347754
# Train time 01h 29m 01s Epoch 6 Batch 650 Frame 5200 Avg_dis:0.010791354230605066
# Train time 01h 29m 12s Epoch 6 Batch 675 Frame 5400 Avg_dis:0.007771574630169198
# Train time 01h 29m 23s Epoch 6 Batch 700 Frame 5600 Avg_dis:0.00642652454553172
# Train time 01h 29m 34s Epoch 6 Batch 725 Frame 5800 Avg_dis:0.010306622920325026
# Train time 01h 29m 45s Epoch 6 Batch 750 Frame 6000 Avg_dis:0.006873874575830996
# Train time 01h 29m 56s Epoch 6 Batch 775 Frame 6200 Avg_dis:0.022259527118876576
# Train time 01h 30m 07s Epoch 6 Batch 800 Frame 6400 Avg_dis:0.012473948241677135
# Train time 01h 30m 18s Epoch 6 Batch 825 Frame 6600 Avg_dis:0.009815980156417936
# Train time 01h 30m 29s Epoch 6 Batch 850 Frame 6800 Avg_dis:0.009088146733120084
# Train time 01h 30m 40s Epoch 6 Batch 875 Frame 7000 Avg_dis:0.006133440008852631
# Train time 01h 30m 50s Epoch 6 Batch 900 Frame 7200 Avg_dis:0.011438250192441046
# Train time 01h 31m 01s Epoch 6 Batch 925 Frame 7400 Avg_dis:0.008874989580363035
# Train time 01h 31m 12s Epoch 6 Batch 950 Frame 7600 Avg_dis:0.009568733861669898
# Train time 01h 31m 23s Epoch 6 Batch 975 Frame 7800 Avg_dis:0.009683700161986053
# Train time 01h 31m 34s Epoch 6 Batch 1000 Frame 8000 Avg_dis:0.008120342215988785
# Train time 01h 31m 45s Epoch 6 Batch 1025 Frame 8200 Avg_dis:0.008935898018535227
# Train time 01h 31m 56s Epoch 6 Batch 1050 Frame 8400 Avg_dis:0.011050550383515656
# Train time 01h 32m 07s Epoch 6 Batch 1075 Frame 8600 Avg_dis:0.007457852829247713
# Train time 01h 32m 17s Epoch 6 Batch 1100 Frame 8800 Avg_dis:0.011529206996783614
# Train time 01h 32m 28s Epoch 6 Batch 1125 Frame 9000 Avg_dis:0.007531955256126821
# Train time 01h 32m 39s Epoch 6 Batch 1150 Frame 9200 Avg_dis:0.010182411700952798
# Train time 01h 32m 50s Epoch 6 Batch 1175 Frame 9400 Avg_dis:0.011001041391864419
# Train time 01h 33m 01s Epoch 6 Batch 1200 Frame 9600 Avg_dis:0.0058719452790683135
# Train time 01h 33m 11s Epoch 6 Batch 1225 Frame 9800 Avg_dis:0.011876223026774824
# Train time 01h 33m 22s Epoch 6 Batch 1250 Frame 10000 Avg_dis:0.015135677240323275
# Train time 01h 33m 33s Epoch 6 Batch 1275 Frame 10200 Avg_dis:0.011136181012261659
# Train time 01h 33m 44s Epoch 6 Batch 1300 Frame 10400 Avg_dis:0.01098607067251578
# Train time 01h 33m 55s Epoch 6 Batch 1325 Frame 10600 Avg_dis:0.018360346497502178
# Train time 01h 34m 05s Epoch 6 Batch 1350 Frame 10800 Avg_dis:0.008896130311768502
# Train time 01h 34m 17s Epoch 6 Batch 1375 Frame 11000 Avg_dis:0.009713572449982166
# Train time 01h 34m 27s Epoch 6 Batch 1400 Frame 11200 Avg_dis:0.007676936715142801
# Train time 01h 34m 38s Epoch 6 Batch 1425 Frame 11400 Avg_dis:0.010985157685354352
# Train time 01h 34m 49s Epoch 6 Batch 1450 Frame 11600 Avg_dis:0.013372070039622486
# Train time 01h 35m 00s Epoch 6 Batch 1475 Frame 11800 Avg_dis:0.008274465159047395
# Train time 01h 35m 11s Epoch 6 Batch 1500 Frame 12000 Avg_dis:0.013139896793290973
# Train time 01h 35m 21s Epoch 6 Batch 1525 Frame 12200 Avg_dis:0.008972683979663998
# Train time 01h 35m 32s Epoch 6 Batch 1550 Frame 12400 Avg_dis:0.008909044147003442
# Train time 01h 35m 43s Epoch 6 Batch 1575 Frame 12600 Avg_dis:0.009272766706999391
# Train time 01h 35m 54s Epoch 6 Batch 1600 Frame 12800 Avg_dis:0.010187110456172377
# Train time 01h 36m 05s Epoch 6 Batch 1625 Frame 13000 Avg_dis:0.010192390996962786
# Train time 01h 36m 16s Epoch 6 Batch 1650 Frame 13200 Avg_dis:0.010320424800738692
# Train time 01h 36m 27s Epoch 6 Batch 1675 Frame 13400 Avg_dis:0.011291091504972428
# Train time 01h 36m 37s Epoch 6 Batch 1700 Frame 13600 Avg_dis:0.017266272858250886
# Train time 01h 36m 48s Epoch 6 Batch 1725 Frame 13800 Avg_dis:0.009968062164261937
# Train time 01h 36m 59s Epoch 6 Batch 1750 Frame 14000 Avg_dis:0.009274547221139073
# Train time 01h 37m 10s Epoch 6 Batch 1775 Frame 14200 Avg_dis:0.01720047416165471
# Train time 01h 37m 21s Epoch 6 Batch 1800 Frame 14400 Avg_dis:0.02361044706776738
# Train time 01h 37m 32s Epoch 6 Batch 1825 Frame 14600 Avg_dis:0.011105528799816966
# Train time 01h 37m 43s Epoch 6 Batch 1850 Frame 14800 Avg_dis:0.010940431500785053
# Train time 01h 37m 54s Epoch 6 Batch 1875 Frame 15000 Avg_dis:0.012740593287162483
# Train time 01h 38m 04s Epoch 6 Batch 1900 Frame 15200 Avg_dis:0.01244811579817906
# Train time 01h 38m 15s Epoch 6 Batch 1925 Frame 15400 Avg_dis:0.008985573309473693
# Train time 01h 38m 27s Epoch 6 Batch 1950 Frame 15600 Avg_dis:0.008827802259474993
# Train time 01h 38m 37s Epoch 6 Batch 1975 Frame 15800 Avg_dis:0.008215299632865936
# Train time 01h 38m 48s Epoch 6 Batch 2000 Frame 16000 Avg_dis:0.008828864607494324
# Train time 01h 38m 59s Epoch 6 Batch 2025 Frame 16200 Avg_dis:0.010848315490875393
# Train time 01h 39m 10s Epoch 6 Batch 2050 Frame 16400 Avg_dis:0.01016853260807693
# Train time 01h 39m 21s Epoch 6 Batch 2075 Frame 16600 Avg_dis:0.013909899367718026
# Train time 01h 39m 32s Epoch 6 Batch 2100 Frame 16800 Avg_dis:0.013420699688140303
# Train time 01h 39m 43s Epoch 6 Batch 2125 Frame 17000 Avg_dis:0.00894407433224842
# Train time 01h 39m 53s Epoch 6 Batch 2150 Frame 17200 Avg_dis:0.012470038782339543
# Train time 01h 40m 04s Epoch 6 Batch 2175 Frame 17400 Avg_dis:0.011477675230707973
# Train time 01h 40m 15s Epoch 6 Batch 2200 Frame 17600 Avg_dis:0.009833947173319757
# Train time 01h 40m 26s Epoch 6 Batch 2225 Frame 17800 Avg_dis:0.011827605369035155
# Train time 01h 40m 37s Epoch 6 Batch 2250 Frame 18000 Avg_dis:0.01100968907121569
# Train time 01h 40m 48s Epoch 6 Batch 2275 Frame 18200 Avg_dis:0.010651311953552067
# >>>>>>>>----------epoch 6 train finish---------<<<<<<<<
# Test time 01h 41m 09s Epoch 6 TEST FINISH Avg dis: 0.014336309185504768
# 6 >>>>>>>>----------BEST TEST MODEL SAVED---------<<<<<<<<
# Train time 01h 41m 09s, Training started
# Train time 01h 41m 20s Epoch 7 Batch 25 Frame 200 Avg_dis:0.010156199801713228
# Train time 01h 41m 31s Epoch 7 Batch 50 Frame 400 Avg_dis:0.009631314896978438
# Train time 01h 41m 42s Epoch 7 Batch 75 Frame 600 Avg_dis:0.008969046466518193
# Train time 01h 41m 52s Epoch 7 Batch 100 Frame 800 Avg_dis:0.010532435262575746
# Train time 01h 42m 04s Epoch 7 Batch 125 Frame 1000 Avg_dis:0.01655476150335744
# Train time 01h 42m 14s Epoch 7 Batch 150 Frame 1200 Avg_dis:0.011798111372627318
# Train time 01h 42m 25s Epoch 7 Batch 175 Frame 1400 Avg_dis:0.010397053905762732
# Train time 01h 42m 36s Epoch 7 Batch 200 Frame 1600 Avg_dis:0.011418032983783633
# Train time 01h 42m 47s Epoch 7 Batch 225 Frame 1800 Avg_dis:0.013499226362910122
# Train time 01h 42m 58s Epoch 7 Batch 250 Frame 2000 Avg_dis:0.011208510375581682
# Train time 01h 43m 09s Epoch 7 Batch 275 Frame 2200 Avg_dis:0.009084287739824504
# Train time 01h 43m 20s Epoch 7 Batch 300 Frame 2400 Avg_dis:0.0077165745897218585
# Train time 01h 43m 30s Epoch 7 Batch 325 Frame 2600 Avg_dis:0.008771262160735205
# Train time 01h 43m 41s Epoch 7 Batch 350 Frame 2800 Avg_dis:0.01301764213712886
# Train time 01h 43m 52s Epoch 7 Batch 375 Frame 3000 Avg_dis:0.010556141089182347
# Train time 01h 44m 03s Epoch 7 Batch 400 Frame 3200 Avg_dis:0.012236916547408327
# Train time 01h 44m 14s Epoch 7 Batch 425 Frame 3400 Avg_dis:0.009873411385342479
# Train time 01h 44m 24s Epoch 7 Batch 450 Frame 3600 Avg_dis:0.009921058837790042
# Train time 01h 44m 35s Epoch 7 Batch 475 Frame 3800 Avg_dis:0.009799289633519948
# Train time 01h 44m 46s Epoch 7 Batch 500 Frame 4000 Avg_dis:0.010029871569713578
# Train time 01h 44m 57s Epoch 7 Batch 525 Frame 4200 Avg_dis:0.01019119773991406
# Train time 01h 45m 08s Epoch 7 Batch 550 Frame 4400 Avg_dis:0.009836978104431182
# Train time 01h 45m 19s Epoch 7 Batch 575 Frame 4600 Avg_dis:0.012647234194446355
# Train time 01h 45m 30s Epoch 7 Batch 600 Frame 4800 Avg_dis:0.01301456947112456
# Train time 01h 45m 40s Epoch 7 Batch 625 Frame 5000 Avg_dis:0.008401186321862042
# Train time 01h 45m 51s Epoch 7 Batch 650 Frame 5200 Avg_dis:0.011708120116963983
# Train time 01h 46m 02s Epoch 7 Batch 675 Frame 5400 Avg_dis:0.01226896300795488
# Train time 01h 46m 13s Epoch 7 Batch 700 Frame 5600 Avg_dis:0.008781457203440368
# Train time 01h 46m 24s Epoch 7 Batch 725 Frame 5800 Avg_dis:0.012550595856737345
# Train time 01h 46m 35s Epoch 7 Batch 750 Frame 6000 Avg_dis:0.01245292293606326
# Train time 01h 46m 46s Epoch 7 Batch 775 Frame 6200 Avg_dis:0.00941343532758765
# Train time 01h 46m 56s Epoch 7 Batch 800 Frame 6400 Avg_dis:0.010283588897436857
# Train time 01h 47m 07s Epoch 7 Batch 825 Frame 6600 Avg_dis:0.010916944302152842
# Train time 01h 47m 18s Epoch 7 Batch 850 Frame 6800 Avg_dis:0.011252303374931216
# Train time 01h 47m 29s Epoch 7 Batch 875 Frame 7000 Avg_dis:0.00981890654657036
# Train time 01h 47m 40s Epoch 7 Batch 900 Frame 7200 Avg_dis:0.009581518184859306
# Train time 01h 47m 51s Epoch 7 Batch 925 Frame 7400 Avg_dis:0.007656070403754711
# Train time 01h 48m 02s Epoch 7 Batch 950 Frame 7600 Avg_dis:0.014644434733781964
# Train time 01h 48m 12s Epoch 7 Batch 975 Frame 7800 Avg_dis:0.015615364769473672
# Train time 01h 48m 23s Epoch 7 Batch 1000 Frame 8000 Avg_dis:0.008716871525393799
# Train time 01h 48m 34s Epoch 7 Batch 1025 Frame 8200 Avg_dis:0.01313394505996257
# Train time 01h 48m 45s Epoch 7 Batch 1050 Frame 8400 Avg_dis:0.011114177817944437
# Train time 01h 48m 56s Epoch 7 Batch 1075 Frame 8600 Avg_dis:0.009516398247797042
# Train time 01h 49m 06s Epoch 7 Batch 1100 Frame 8800 Avg_dis:0.006996643001912162
# Train time 01h 49m 17s Epoch 7 Batch 1125 Frame 9000 Avg_dis:0.010983409185428172
# Train time 01h 49m 28s Epoch 7 Batch 1150 Frame 9200 Avg_dis:0.012153695162851363
# Train time 01h 49m 39s Epoch 7 Batch 1175 Frame 9400 Avg_dis:0.009341656987089664
# Train time 01h 49m 50s Epoch 7 Batch 1200 Frame 9600 Avg_dis:0.011665487138088793
# Train time 01h 50m 01s Epoch 7 Batch 1225 Frame 9800 Avg_dis:0.011729389720130712
# Train time 01h 50m 12s Epoch 7 Batch 1250 Frame 10000 Avg_dis:0.011754159408155829
# Train time 01h 50m 23s Epoch 7 Batch 1275 Frame 10200 Avg_dis:0.009834768861765042
# Train time 01h 50m 34s Epoch 7 Batch 1300 Frame 10400 Avg_dis:0.009765206428710371
# Train time 01h 50m 45s Epoch 7 Batch 1325 Frame 10600 Avg_dis:0.012782852514646947
# Train time 01h 50m 55s Epoch 7 Batch 1350 Frame 10800 Avg_dis:0.013353806862141937
# Train time 01h 51m 06s Epoch 7 Batch 1375 Frame 11000 Avg_dis:0.010118337697349489
# Train time 01h 51m 17s Epoch 7 Batch 1400 Frame 11200 Avg_dis:0.007650681829545647
# Train time 01h 51m 28s Epoch 7 Batch 1425 Frame 11400 Avg_dis:0.00817060237750411
# Train time 01h 51m 39s Epoch 7 Batch 1450 Frame 11600 Avg_dis:0.010945405054371804
# Train time 01h 51m 50s Epoch 7 Batch 1475 Frame 11800 Avg_dis:0.009173265018034726
# Train time 01h 52m 01s Epoch 7 Batch 1500 Frame 12000 Avg_dis:0.011752022575819865
# Train time 01h 52m 12s Epoch 7 Batch 1525 Frame 12200 Avg_dis:0.00940111157251522
# Train time 01h 52m 22s Epoch 7 Batch 1550 Frame 12400 Avg_dis:0.012652495235670358
# Train time 01h 52m 33s Epoch 7 Batch 1575 Frame 12600 Avg_dis:0.008337339444551617
# Train time 01h 52m 44s Epoch 7 Batch 1600 Frame 12800 Avg_dis:0.01263247278984636
# Train time 01h 52m 55s Epoch 7 Batch 1625 Frame 13000 Avg_dis:0.009660160285420716
# Train time 01h 53m 06s Epoch 7 Batch 1650 Frame 13200 Avg_dis:0.0072382212383672595
# Train time 01h 53m 17s Epoch 7 Batch 1675 Frame 13400 Avg_dis:0.007514271681429818
# Train time 01h 53m 28s Epoch 7 Batch 1700 Frame 13600 Avg_dis:0.009613089612685144
# Train time 01h 53m 39s Epoch 7 Batch 1725 Frame 13800 Avg_dis:0.012028423137962818
# Train time 01h 53m 49s Epoch 7 Batch 1750 Frame 14000 Avg_dis:0.012413766351528466
# Train time 01h 54m 00s Epoch 7 Batch 1775 Frame 14200 Avg_dis:0.010693557764170691
# Train time 01h 54m 11s Epoch 7 Batch 1800 Frame 14400 Avg_dis:0.01478175655938685
# Train time 01h 54m 22s Epoch 7 Batch 1825 Frame 14600 Avg_dis:0.015498980123084038
# Train time 01h 54m 33s Epoch 7 Batch 1850 Frame 14800 Avg_dis:0.009292976727010682
# Train time 01h 54m 44s Epoch 7 Batch 1875 Frame 15000 Avg_dis:0.0123593361931853
# Train time 01h 54m 55s Epoch 7 Batch 1900 Frame 15200 Avg_dis:0.01101916836341843
# Train time 01h 55m 05s Epoch 7 Batch 1925 Frame 15400 Avg_dis:0.010109925031429157
# Train time 01h 55m 17s Epoch 7 Batch 1950 Frame 15600 Avg_dis:0.014127550122793764
# Train time 01h 55m 27s Epoch 7 Batch 1975 Frame 15800 Avg_dis:0.012364093534415588
# Train time 01h 55m 38s Epoch 7 Batch 2000 Frame 16000 Avg_dis:0.014908642915543169
# Train time 01h 55m 49s Epoch 7 Batch 2025 Frame 16200 Avg_dis:0.008309613622259349
# Train time 01h 55m 59s Epoch 7 Batch 2050 Frame 16400 Avg_dis:0.007807914458680898
# Train time 01h 56m 10s Epoch 7 Batch 2075 Frame 16600 Avg_dis:0.008640482788905501
# Train time 01h 56m 21s Epoch 7 Batch 2100 Frame 16800 Avg_dis:0.009391650033649057
# Train time 01h 56m 32s Epoch 7 Batch 2125 Frame 17000 Avg_dis:0.008913685072911903
# Train time 01h 56m 43s Epoch 7 Batch 2150 Frame 17200 Avg_dis:0.015231788740493357
# Train time 01h 56m 54s Epoch 7 Batch 2175 Frame 17400 Avg_dis:0.011837251367978752
# Train time 01h 57m 05s Epoch 7 Batch 2200 Frame 17600 Avg_dis:0.00628620115458034
# Train time 01h 57m 15s Epoch 7 Batch 2225 Frame 17800 Avg_dis:0.009410570608451962
# Train time 01h 57m 26s Epoch 7 Batch 2250 Frame 18000 Avg_dis:0.017301223939284682
# Train time 01h 57m 37s Epoch 7 Batch 2275 Frame 18200 Avg_dis:0.010426041029859334
# >>>>>>>>----------epoch 7 train finish---------<<<<<<<<
# Test time 01h 57m 58s Epoch 7 TEST FINISH Avg dis: 0.014365380622211446
# Train time 01h 57m 58s, Training started
# Train time 01h 58m 09s Epoch 8 Batch 25 Frame 200 Avg_dis:0.014261408941820264
# Train time 01h 58m 20s Epoch 8 Batch 50 Frame 400 Avg_dis:0.0074499097536318
# Train time 01h 58m 31s Epoch 8 Batch 75 Frame 600 Avg_dis:0.011989858001470566
# Train time 01h 58m 42s Epoch 8 Batch 100 Frame 800 Avg_dis:0.011231440235860646
# Train time 01h 58m 53s Epoch 8 Batch 125 Frame 1000 Avg_dis:0.0075502346735447645
# Train time 01h 59m 04s Epoch 8 Batch 150 Frame 1200 Avg_dis:0.009693455300293863
# Train time 01h 59m 14s Epoch 8 Batch 175 Frame 1400 Avg_dis:0.011545672139618546
# Train time 01h 59m 25s Epoch 8 Batch 200 Frame 1600 Avg_dis:0.010876622924115509
# Train time 01h 59m 36s Epoch 8 Batch 225 Frame 1800 Avg_dis:0.009410722821485251
# Train time 01h 59m 47s Epoch 8 Batch 250 Frame 2000 Avg_dis:0.013026651227846742
# Train time 01h 59m 58s Epoch 8 Batch 275 Frame 2200 Avg_dis:0.010012679733335972
# Train time 02h 00m 09s Epoch 8 Batch 300 Frame 2400 Avg_dis:0.012210095243062824
# Train time 02h 00m 20s Epoch 8 Batch 325 Frame 2600 Avg_dis:0.012419921986293048
# Train time 02h 00m 31s Epoch 8 Batch 350 Frame 2800 Avg_dis:0.015204138966510072
# Train time 02h 00m 42s Epoch 8 Batch 375 Frame 3000 Avg_dis:0.008065562578849494
# Train time 02h 00m 52s Epoch 8 Batch 400 Frame 3200 Avg_dis:0.011422367708291858
# Train time 02h 01m 03s Epoch 8 Batch 425 Frame 3400 Avg_dis:0.007386459736153483
# Train time 02h 01m 14s Epoch 8 Batch 450 Frame 3600 Avg_dis:0.010934921097941697
# Train time 02h 01m 25s Epoch 8 Batch 475 Frame 3800 Avg_dis:0.008200082462280989
# Train time 02h 01m 36s Epoch 8 Batch 500 Frame 4000 Avg_dis:0.013891812413930893
# Train time 02h 01m 47s Epoch 8 Batch 525 Frame 4200 Avg_dis:0.007962660340126604
# Train time 02h 01m 58s Epoch 8 Batch 550 Frame 4400 Avg_dis:0.012127755209803581
# Train time 02h 02m 09s Epoch 8 Batch 575 Frame 4600 Avg_dis:0.009854702861048281
# Train time 02h 02m 20s Epoch 8 Batch 600 Frame 4800 Avg_dis:0.012323906819801778
# Train time 02h 02m 31s Epoch 8 Batch 625 Frame 5000 Avg_dis:0.010685502260457724
# Train time 02h 02m 41s Epoch 8 Batch 650 Frame 5200 Avg_dis:0.009573841351084411
# Train time 02h 02m 52s Epoch 8 Batch 675 Frame 5400 Avg_dis:0.010989069705829024
# Train time 02h 03m 03s Epoch 8 Batch 700 Frame 5600 Avg_dis:0.017024921369738877
# Train time 02h 03m 14s Epoch 8 Batch 725 Frame 5800 Avg_dis:0.007792930933646858
# Train time 02h 03m 25s Epoch 8 Batch 750 Frame 6000 Avg_dis:0.009459184831939638
# Train time 02h 03m 36s Epoch 8 Batch 775 Frame 6200 Avg_dis:0.01076169143198058
# Train time 02h 03m 47s Epoch 8 Batch 800 Frame 6400 Avg_dis:0.006876476923935115
# Train time 02h 03m 58s Epoch 8 Batch 825 Frame 6600 Avg_dis:0.009967721649445593
# Train time 02h 04m 09s Epoch 8 Batch 850 Frame 6800 Avg_dis:0.012748506793286651
# Train time 02h 04m 20s Epoch 8 Batch 875 Frame 7000 Avg_dis:0.009192513069137931
# Train time 02h 04m 31s Epoch 8 Batch 900 Frame 7200 Avg_dis:0.014481750491540879
# Train time 02h 04m 42s Epoch 8 Batch 925 Frame 7400 Avg_dis:0.0347592526813969
# Train time 02h 04m 53s Epoch 8 Batch 950 Frame 7600 Avg_dis:0.011821203195722774
# Train time 02h 05m 03s Epoch 8 Batch 975 Frame 7800 Avg_dis:0.009243308159057051
# Train time 02h 05m 14s Epoch 8 Batch 1000 Frame 8000 Avg_dis:0.00881622772431001
# Train time 02h 05m 25s Epoch 8 Batch 1025 Frame 8200 Avg_dis:0.011957680864725262
# Train time 02h 05m 36s Epoch 8 Batch 1050 Frame 8400 Avg_dis:0.009920845797751099
# Train time 02h 05m 47s Epoch 8 Batch 1075 Frame 8600 Avg_dis:0.01041231513954699
# Train time 02h 05m 58s Epoch 8 Batch 1100 Frame 8800 Avg_dis:0.01112679933430627
# Train time 02h 06m 08s Epoch 8 Batch 1125 Frame 9000 Avg_dis:0.010402829677332193
# Train time 02h 06m 20s Epoch 8 Batch 1150 Frame 9200 Avg_dis:0.008398117439355701
# Train time 02h 06m 31s Epoch 8 Batch 1175 Frame 9400 Avg_dis:0.011528600880410522
# Train time 02h 06m 41s Epoch 8 Batch 1200 Frame 9600 Avg_dis:0.011212469486054033
# Train time 02h 06m 52s Epoch 8 Batch 1225 Frame 9800 Avg_dis:0.008715686592040583
# Train time 02h 07m 03s Epoch 8 Batch 1250 Frame 10000 Avg_dis:0.008937754813814536
# Train time 02h 07m 14s Epoch 8 Batch 1275 Frame 10200 Avg_dis:0.009385930316057056
# Train time 02h 07m 25s Epoch 8 Batch 1300 Frame 10400 Avg_dis:0.010235937719698995
# Train time 02h 07m 36s Epoch 8 Batch 1325 Frame 10600 Avg_dis:0.009214515885105357
# Train time 02h 07m 46s Epoch 8 Batch 1350 Frame 10800 Avg_dis:0.012559901049826294
# Train time 02h 07m 58s Epoch 8 Batch 1375 Frame 11000 Avg_dis:0.014761747210286558
# Train time 02h 08m 09s Epoch 8 Batch 1400 Frame 11200 Avg_dis:0.009434681735001504
# Train time 02h 08m 20s Epoch 8 Batch 1425 Frame 11400 Avg_dis:0.010812740307301283
# Train time 02h 08m 31s Epoch 8 Batch 1450 Frame 11600 Avg_dis:0.01328999933321029
# Train time 02h 08m 41s Epoch 8 Batch 1475 Frame 11800 Avg_dis:0.01575422944733873
# Train time 02h 08m 52s Epoch 8 Batch 1500 Frame 12000 Avg_dis:0.009889706794638187
# Train time 02h 09m 03s Epoch 8 Batch 1525 Frame 12200 Avg_dis:0.007307466439669952
# Train time 02h 09m 14s Epoch 8 Batch 1550 Frame 12400 Avg_dis:0.006592793186428025
# Train time 02h 09m 25s Epoch 8 Batch 1575 Frame 12600 Avg_dis:0.010302156704710796
# Train time 02h 09m 36s Epoch 8 Batch 1600 Frame 12800 Avg_dis:0.011178251588717103
# Train time 02h 09m 47s Epoch 8 Batch 1625 Frame 13000 Avg_dis:0.01100045972270891
# Train time 02h 09m 58s Epoch 8 Batch 1650 Frame 13200 Avg_dis:0.008697800454683602
# Train time 02h 10m 09s Epoch 8 Batch 1675 Frame 13400 Avg_dis:0.0072540537803433836
# Train time 02h 10m 19s Epoch 8 Batch 1700 Frame 13600 Avg_dis:0.016426376183517277
# Train time 02h 10m 31s Epoch 8 Batch 1725 Frame 13800 Avg_dis:0.009162650152575225
# Train time 02h 10m 42s Epoch 8 Batch 1750 Frame 14000 Avg_dis:0.020557520678266883
# Train time 02h 10m 52s Epoch 8 Batch 1775 Frame 14200 Avg_dis:0.014177033386658877
# Train time 02h 11m 03s Epoch 8 Batch 1800 Frame 14400 Avg_dis:0.013144151831511408
# Train time 02h 11m 14s Epoch 8 Batch 1825 Frame 14600 Avg_dis:0.011746012489311397
# Train time 02h 11m 25s Epoch 8 Batch 1850 Frame 14800 Avg_dis:0.010645438567735255
# Train time 02h 11m 36s Epoch 8 Batch 1875 Frame 15000 Avg_dis:0.011328091728501022
# Train time 02h 11m 47s Epoch 8 Batch 1900 Frame 15200 Avg_dis:0.008930651121772826
# Train time 02h 11m 58s Epoch 8 Batch 1925 Frame 15400 Avg_dis:0.00882671249564737
# Train time 02h 12m 09s Epoch 8 Batch 1950 Frame 15600 Avg_dis:0.007943132484797388
# Train time 02h 12m 20s Epoch 8 Batch 1975 Frame 15800 Avg_dis:0.009600367455277592
# Train time 02h 12m 30s Epoch 8 Batch 2000 Frame 16000 Avg_dis:0.009743584494572133
# Train time 02h 12m 41s Epoch 8 Batch 2025 Frame 16200 Avg_dis:0.009419603797141463
# Train time 02h 12m 52s Epoch 8 Batch 2050 Frame 16400 Avg_dis:0.013558338803704828
# Train time 02h 13m 03s Epoch 8 Batch 2075 Frame 16600 Avg_dis:0.012438964913599193
# Train time 02h 13m 14s Epoch 8 Batch 2100 Frame 16800 Avg_dis:0.0074570561409927905
# Train time 02h 13m 25s Epoch 8 Batch 2125 Frame 17000 Avg_dis:0.010583916679024696
# Train time 02h 13m 36s Epoch 8 Batch 2150 Frame 17200 Avg_dis:0.010578192945104092
# Train time 02h 13m 47s Epoch 8 Batch 2175 Frame 17400 Avg_dis:0.010496112750843167
# Train time 02h 13m 58s Epoch 8 Batch 2200 Frame 17600 Avg_dis:0.008633436664240435
# Train time 02h 14m 09s Epoch 8 Batch 2225 Frame 17800 Avg_dis:0.009545386012177914
# Train time 02h 14m 20s Epoch 8 Batch 2250 Frame 18000 Avg_dis:0.007996491563972086
# Train time 02h 14m 31s Epoch 8 Batch 2275 Frame 18200 Avg_dis:0.011300459736958146
# >>>>>>>>----------epoch 8 train finish---------<<<<<<<<
# Test time 02h 14m 52s Epoch 8 TEST FINISH Avg dis: 0.0141665309744444
# 8 >>>>>>>>----------BEST TEST MODEL SAVED---------<<<<<<<<
# Train time 02h 14m 52s, Training started
# Train time 02h 15m 03s Epoch 9 Batch 25 Frame 200 Avg_dis:0.0110806999146007
# Train time 02h 15m 14s Epoch 9 Batch 50 Frame 400 Avg_dis:0.009679740178398788
# Train time 02h 15m 25s Epoch 9 Batch 75 Frame 600 Avg_dis:0.014246077684219927
# Train time 02h 15m 36s Epoch 9 Batch 100 Frame 800 Avg_dis:0.009715446853078902
# Train time 02h 15m 47s Epoch 9 Batch 125 Frame 1000 Avg_dis:0.01146505807992071
# Train time 02h 15m 58s Epoch 9 Batch 150 Frame 1200 Avg_dis:0.01190529577434063
# Train time 02h 16m 09s Epoch 9 Batch 175 Frame 1400 Avg_dis:0.008467007661238313
# Train time 02h 16m 20s Epoch 9 Batch 200 Frame 1600 Avg_dis:0.01476354181068018
# Train time 02h 16m 31s Epoch 9 Batch 225 Frame 1800 Avg_dis:0.008578524400945753
# Train time 02h 16m 42s Epoch 9 Batch 250 Frame 2000 Avg_dis:0.006520828290376812
# Train time 02h 16m 53s Epoch 9 Batch 275 Frame 2200 Avg_dis:0.008288497221656144
# Train time 02h 17m 04s Epoch 9 Batch 300 Frame 2400 Avg_dis:0.012746244727168232
# Train time 02h 17m 15s Epoch 9 Batch 325 Frame 2600 Avg_dis:0.012200671772006899
# Train time 02h 17m 26s Epoch 9 Batch 350 Frame 2800 Avg_dis:0.013979517156258225
# Train time 02h 17m 37s Epoch 9 Batch 375 Frame 3000 Avg_dis:0.00978145404951647
# Train time 02h 17m 48s Epoch 9 Batch 400 Frame 3200 Avg_dis:0.013296317483764142
# Train time 02h 17m 58s Epoch 9 Batch 425 Frame 3400 Avg_dis:0.00912713777506724
# Train time 02h 18m 09s Epoch 9 Batch 450 Frame 3600 Avg_dis:0.011080637690611184
# Train time 02h 18m 21s Epoch 9 Batch 475 Frame 3800 Avg_dis:0.013702319469302893
# Train time 02h 18m 31s Epoch 9 Batch 500 Frame 4000 Avg_dis:0.010815380199346691
# Train time 02h 18m 42s Epoch 9 Batch 525 Frame 4200 Avg_dis:0.012301553855650127
# Train time 02h 18m 53s Epoch 9 Batch 550 Frame 4400 Avg_dis:0.009567076107487082
# Train time 02h 19m 04s Epoch 9 Batch 575 Frame 4600 Avg_dis:0.008159214921761304
# ...
# Train time 03h 29m 19s Epoch 13 Batch 925 Frame 7400 Avg_dis:0.009749651711899787
# Train time 03h 29m 30s Epoch 13 Batch 950 Frame 7600 Avg_dis:0.010056312254164368
# Train time 03h 29m 41s Epoch 13 Batch 975 Frame 7800 Avg_dis:0.014039469242561609
# Train time 03h 52m 15s Epoch 14 Batch 1750 Frame 14000 Avg_dis:0.008363251719856635
# Train time 03h 52m 26s Epoch 14 Batch 1775 Frame 14200 Avg_dis:0.011576072662137449
# Train time 03h 52m 36s Epoch 14 Batch 1800 Frame 14400 Avg_dis:0.008317376516060904
# Train time 03h 52m 47s Epoch 14 Batch 1825 Frame 14600 Avg_dis:0.010328471194952726
# Train time 03h 52m 58s Epoch 14 Batch 1850 Frame 14800 Avg_dis:0.009405069635249674
# Train time 03h 53m 09s Epoch 14 Batch 1875 Frame 15000 Avg_dis:0.012770666042342782
# Train time 03h 53m 20s Epoch 14 Batch 1900 Frame 15200 Avg_dis:0.008846417476888746
# Train time 03h 53m 31s Epoch 14 Batch 1925 Frame 15400 Avg_dis:0.010501120879780501
# Train time 03h 53m 42s Epoch 14 Batch 1950 Frame 15600 Avg_dis:0.009881927369860932
# Train time 03h 53m 53s Epoch 14 Batch 1975 Frame 15800 Avg_dis:0.00905064184917137
# Train time 03h 54m 04s Epoch 14 Batch 2000 Frame 16000 Avg_dis:0.01172832038719207
# Train time 03h 54m 15s Epoch 14 Batch 2025 Frame 16200 Avg_dis:0.010728870809543878
# Train time 03h 54m 26s Epoch 14 Batch 2050 Frame 16400 Avg_dis:0.007137524022255093
# Train time 03h 54m 37s Epoch 14 Batch 2075 Frame 16600 Avg_dis:0.0064024199382402
# Train time 03h 54m 48s Epoch 14 Batch 2100 Frame 16800 Avg_dis:0.007273745897691697
# Train time 03h 54m 59s Epoch 14 Batch 2125 Frame 17000 Avg_dis:0.00816711038351059
# Train time 03h 55m 10s Epoch 14 Batch 2150 Frame 17200 Avg_dis:0.008100234204903245
# Train time 03h 55m 21s Epoch 14 Batch 2175 Frame 17400 Avg_dis:0.00659328477922827
# Train time 03h 55m 32s Epoch 14 Batch 2200 Frame 17600 Avg_dis:0.007597480493132025
# Train time 03h 55m 43s Epoch 14 Batch 2225 Frame 17800 Avg_dis:0.008309588534757495
# Train time 03h 55m 53s Epoch 14 Batch 2250 Frame 18000 Avg_dis:0.009063883044291288
# Train time 03h 56m 04s Epoch 14 Batch 2275 Frame 18200 Avg_dis:0.0173647019546479
# >>>>>>>>----------epoch 14 train finish---------<<<<<<<<
# Test time 03h 56m 25s Epoch 14 TEST FINISH Avg dis: 0.013528227346759398
# 14 >>>>>>>>----------BEST TEST MODEL SAVED---------<<<<<<<<
# Train time 03h 56m 26s, Training started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-49d22c4e3f5d> in <module>
#      30                                                              Variable(idx).cuda()
#      31
# ---> 32             pred_r, pred_t, pred_c, emb = estimator(img, choose, idx)
#      33             loss, dis, _, _ = criterion(pred_r, pred_t, pred_c, target,
#      34                                   model_points, idx,
#
# ~/.conda/envs/visual/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/DenseFusion/lib/network.py in forward(self, img, choose, obj)
#      56
#      57     def forward(self, img, choose, obj):
# ---> 58         out_img = self.cnn(img)
#      59
#      60         bs, di, _, _ = out_img.size()
#
# ~/.conda/envs/visual/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/DenseFusion/lib/network.py in forward(self, x)
#     107
#     108     def forward(self, x):
# --> 109         x = self.model(x)
#     110         return x
#     111
#
# ~/.conda/envs/visual/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/.conda/envs/visual/lib/python3.6/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     148         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#     149         if len(self.device_ids) == 1:
# --> 150             return self.module(*inputs[0], **kwargs[0])
#     151         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     152         outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# ~/.conda/envs/visual/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/DenseFusion/lib/pspnet.py in forward(self, x)
#      71
#      72         p = self.up_2(p)
# ---> 73         p = self.drop_2(p)
#      74
#      75         p = self.up_3(p)
#
# ~/.conda/envs/visual/lib/python3.6/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     584             if name in _buffers:
#     585                 return _buffers[name]
# --> 586         if '_modules' in self.__dict__:
#     587             modules = self.__dict__['_modules']
#     588             if name in modules:
#
# KeyboardInterrupt:

# %%
t = next(iter(dataloader))

# %%
points, choose, img, target, model_points, idx = t

# %%
points.shape
# Out:
# torch.Size([1, 500, 3])

# %%
points
# Out:
# tensor([[[-0.0631, -0.1219,  1.0574],
#          [-0.0650, -0.1200,  1.0574],
#          [-0.0670, -0.1185,  1.0604],
#          ...,
#          [-0.0254, -0.0375,  1.0414],
#          [-0.0217, -0.0376,  1.0444],
#          [-0.0199, -0.0376,  1.0444]]])

# %%
target.shape
# Out:
# torch.Size([1, 500, 3])

# %%
choose.shape
# Out:
# torch.Size([1, 1, 500])

# %%
model_points.shape
# Out:
# torch.Size([1, 500, 3])

# %%
model_points
# Out:
# tensor([[[-0.0658, -0.0487,  0.0008],
#          [-0.0638, -0.0188,  0.0085],
#          [-0.0629, -0.0243,  0.0079],
#          ...,
#          [-0.0101,  0.0565, -0.0162],
#          [-0.0658,  0.0009,  0.0301],
#          [ 0.0184,  0.0379,  0.0174]]])

# %%
img.shape
# Out:
# torch.Size([1, 3, 120, 120])

# %%
choose
# Out:
# tensor([[[ 1409,  1490,  1495,  1528,  1530,  1638,  1646,  1756,  1770,  1771,
#            1855,  1879,  1882,  1885,  1965,  2001,  2016,  2089,  2094,  2098,
#            2103,  2105,  2121,  2122,  2134,  2186,  2199,  2200,  2223,  2227,
#            2235,  2238,  2240,  2249,  2314,  2325,  2340,  2352,  2362,  2373,
#            2425,  2432,  2438,  2452,  2454,  2457,  2474,  2497,  2575,  2583,
#            2591,  2607,  2618,  2665,  2674,  2691,  2696,  2712,  2784,  2785,
#            2797,  2826,  2852,  2906,  2921,  2924,  2949,  2973,  3022,  3032,
#            3046,  3052,  3070,  3078,  3080,  3097,  3142,  3145,  3146,  3147,
#            3155,  3159,  3162,  3182,  3201,  3203,  3204,  3219,  3257,  3269,
#            3275,  3280,  3292,  3305,  3313,  3319,  3320,  3324,  3329,  3330,
#            3340,  3342,  3397,  3408,  3412,  3437,  3448,  3455,  3522,  3523,
#            3526,  3536,  3539,  3541,  3542,  3545,  3548,  3561,  3582,  3622,
#            3625,  3628,  3638,  3663,  3679,  3686,  3692,  3703,  3733,  3744,
